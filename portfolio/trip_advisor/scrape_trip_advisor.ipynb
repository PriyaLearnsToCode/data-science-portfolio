# %%
from selenium import webdriver
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.by import By
import re
import pandas as pd

# %%
class Scrape:
    driver: webdriver.Chrome

    def __init__(self):
        self.driver = webdriver.Chrome()

    def goto(self, link):
        self.driver.get(link)

    def extract_df(self, name, mapper):
        items = self.driver.find_elements(By.CLASS_NAME, name)
        # Same as using map
        # parsed = []
        # for item in items:
        #     parsed.append(mapper(item))
        parsed = map(mapper, items)
        return pd.DataFrame(parsed)
    
    def extract_pages(self, num_pages, url_mapper, root_class, mapper):
        try:
            dfs = []
            for i in range(num_pages):
                url = url_mapper(i + 1)
                self.goto(url)
                df = self.extract_df(root_class, mapper)
                dfs.append(df)
            return pd.concat(dfs)
        finally:
            self.close()
    
    def close(self):
        self.driver.close()

# %%
s = Scrape()

toText = lambda x: x.text

def parseAlibabaElement(el: WebElement):
    price = toText(el.find_element(By.CLASS_NAME, "search-card-e-price-main"))
    title = toText(el.find_element(By.CLASS_NAME, "search-card-e-title"))
    company = next(map(toText, el.find_elements(By.CLASS_NAME, "search-card-e-company")), None)
    review = next(map(toText, el.find_elements(By.CLASS_NAME, "search-card-e-review")), None)
    features = list(map(toText, el.find_elements(By.CLASS_NAME, "search-card-m-sale-features__item")))
    year = next(map(toText, el.find_elements(By.CLASS_NAME, "search-card-e-supplier__year")), None)
    return {
        "price": price,
        "title": title,
        "company": company,
        "review": review,
        "features": features,
        "numFeatures": len(features),
        "year": year
    }

df = s.extract_pages(
    num_pages=10,
    url_mapper=lambda idx: f"https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&categoryId=201394605&keywords=business+in+online&page={idx}",
    root_class="J-search-card-wrapper", 
    mapper=parseAlibabaElement
)

# %%
def extract_review_data(s):
    if s is not None:
        result = re.match(r"([\d|.]+)\n\/([\d|.]+).+(\d+)\b", s, re.M)
        return result.groups()
    else:
        return None
    
def extract_supplier_data(s):
    if s is not None:
        result = re.match(r"(\d+)\syrs?\n(\w+)\b", s, re.M)
        return result.groups()
    else:
        return None

# %%
re.match(r"([\d|.]+)\n\/([\d|.]+).+(\d+)\b", '2.3\n/5.0 (3 reviews)', re.M).groups()
re.match(r"(\d+)\syrs?\n(\w+)\b", '1 yr\nCN Supplier', re.M).groups()
# Out:
# ('1', 'CN')

# %%
review_tupled = df["review"].apply(extract_review_data)
df["rating"] = review_tupled.apply(lambda x: float(x[0]) if x is not None else None)
df["max_rating"] = review_tupled.apply(lambda x: float(x[1]) if x is not None else None)
df["num_reviews"] = review_tupled.apply(lambda x: int(x[2]) if x is not None else None)

# %%
supplier_tupled = df["year"].apply(extract_supplier_data)
df["years_of_experience"] = supplier_tupled.apply(lambda x: int(x[0]) if x is not None else None)
df["supplier_country"] = supplier_tupled.apply(lambda x: str(x[1]) if x is not None else None)

# %%
clean_df = df.drop(columns=["review", "year"])

# %%
clean_df
# Out:
#                     price                                              title  \
# 0   $2,688.00 - $2,999.00  Business Ideas For Online Business Umbrella Ve...
# 1         $11.10 - $13.50  High-Quality to Sell Online 2023 Set With Ther...
# 2         $11.10 - $13.20  2023 unique products to sell online High Quali...
# 3           $1.60 - $3.40  Chinese A5 PU Leather Notebook Gift Box Set Cr...
# 4         $10.90 - $12.00  Gift promotion customized Business business an...
# ..                    ...                                                ...
# 43          $1.23 - $1.89  Magnetic Golf Divot Tool Multi-Functional Golf...
# 44        $10.79 - $12.89  New Product Valentine Wedding Gift Immortal Pr...
# 45          $0.47 - $0.56  Canvas drawstring bags red onion sack mesh net...
# 46        $10.99 - $13.59  Year-end gifts staff employee client notebook ...
# 47        $10.18 - $10.87  New Product Ideas 2023 Electronic Gadgets Neck...
#
#                                          company                  features  \
# 0                                           None       [Min. order: 1 set]
# 1                   Yiwu Tianshu E-Commerce Firm  [Min. order: 100 pieces]
# 2                    Yiwu Fanchuang Trading Firm   [Min. order: 50 pieces]
# 3           Yiwu Yucheng Import&Export Co., Ltd.  [Min. order: 100.0 sets]
# 4   Changsha Jinwo Electronic Commerce Co., Ltd.    [Min. order: 100 sets]
# ..                                           ...                       ...
# 43                          Deer Gifts Co., Ltd.    [Min. order: 2 pieces]
# 44                          Deer Gifts Co., Ltd.     [Min. order: 2 boxes]
# 45                          Deer Gifts Co., Ltd.    [Min. order: 2 pieces]
# 46                          Deer Gifts Co., Ltd.     [Min. order: 2 boxes]
# 47                          Deer Gifts Co., Ltd.     [Min. order: 2 boxes]
#
#     numFeatures  rating  max_rating  num_reviews  years_of_experience  \
# 0             1     2.3         5.0          3.0                    1
# 1             1     4.3         5.0          1.0                    1
# 2             1     NaN         NaN          NaN                    1
# 3             1     4.8         5.0          6.0                    2
# 4             1     4.8         5.0          4.0                    3
# ..          ...     ...         ...          ...                  ...
# 43            1     5.0         5.0          3.0                    1
# 44            1     5.0         5.0          3.0                    1
# 45            1     5.0         5.0          3.0                    1
# 46            1     5.0         5.0          3.0                    1
# 47            1     5.0         5.0          3.0                    1
#
#    supplier_country
# 0                CN
# 1                CN
# 2                CN
# 3                CN
# 4                CN
# ..              ...
# 43               CN
# 44               CN
# 45               CN
# 46               CN
# 47               CN
#
# [480 rows x 10 columns]

# %%
# results_price_range = driver.find_elements(By.CLASS_NAME, "search-card-e-price-main")
# results_price_range

# results_product_name = driver.find_elements(By.CLASS_NAME, "search-card-e-title")
# results_product_name

# results_supplier = driver.find_elements(By.CLASS_NAME, "search-card-e-company")
# results_supplier

# results_supplier_rating = driver.find_elements(By.CLASS_NAME, "search-card-e-review")
# results_supplier_rating

# results_min_order_quantity = driver.find_elements(By.CLASS_NAME, "search-card-m-sale-features__item")
# results_min_order_quantity

# results_supplier_experience = driver.find_elements(By.CLASS_NAME, "search-card-e-supplier__year")
# results_supplier_experience[0].text




# results_complete = driver.find_elements(By.CLASS_NAME, "J-search-card-wrapper")
# results_complete
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_194")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_196")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_197")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_198")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_199")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_201")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_202")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_203")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_204")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_205")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_207")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_208")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_209")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_211")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_212")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_213")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_215")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_216")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_217")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_218")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_221")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_224")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_225")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_226")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_227")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_228")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_229")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_230")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_231")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_232")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_233")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_234")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_235")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_236")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_237")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_240")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7d80b10b0c49b40e3b759f0e483e765f", element="0C8E687589CF117125196EF237889BE0_element_241")>]

# %%
# print(len(results_price_range))
# print(len(results_product_name))
# print(len(results_supplier))
# print(len(results_supplier_rating))
# print(len(results_min_order_quantity))
# print(len(results_supplier_experience))
# Out:
# 48
# 48
# 47
# 44
# 66
# 48

# %%
# prices_list = []

# # Iterate over each result
# for result_element in results_complete:
#     # Extract prices using the specified class name
#     price_elements = result_element.find_elements(By.CLASS_NAME, "search-card-e-price-main")

#     # Check if any price element is found
#     if price_elements:
#         # Extract the text from the first price element (you can adjust this if there are multiple price elements)
#         price_text = price_elements[0].text

#         # Append the extracted price to the list
#         prices_list.append(price_text)

# # Print the extracted prices
# for idx, price in enumerate(prices_list, start=1):
#     print(f"Price {idx}: {price}")
# Out:
# Price 1: $2,500.00 - $2,980.00
# Price 2: $11.10 - $13.50
# Price 3: $11.10 - $13.20
# Price 4: $10.90 - $12.00
# Price 5: $1.60 - $3.40
# Price 6: $12.00 - $13.80
# Price 7: $6.29 - $7.52
# Price 8: $0.45 - $1.88
# Price 9: $16.94 - $28.52
# Price 10: $2.99 - $5.89
# Price 11: $8.70
# Price 12: $8.36
# Price 13: $1.71 - $6.27
# Price 14: $5.63 - $6.98
# Price 15: $0.35 - $0.50
# Price 16: $0.38 - $0.43
# Price 17: $0.95 - $1.10
# Price 18: $10.90 - $13.60
# Price 19: $1.55 - $1.75
# Price 20: $0.12 - $2.99
# Price 21: $5.98 - $9.97
# Price 22: $5.99 - $12.90
# Price 23: $1.40 - $2.50
# Price 24: $4.75 - $5.50
# Price 25: $3.10 - $4.00
# Price 26: $14.40 - $16.00
# Price 27: $14.80 - $19.50
# Price 28: $16.50 - $21.00
# Price 29: $6.53 - $10.87
# Price 30: $1.28 - $1.60
# Price 31: $0.01 - $0.02
# Price 32: $17.75 - $17.99
# Price 33: $19.80 - $25.00
# Price 34: $6.70 - $9.00
# Price 35: $20.13 - $22.90
# Price 36: $0.07 - $0.18
# Price 37: $0.50 - $1.50
# Price 38: $1.17 - $3.50
# Price 39: $11.50 - $12.50
# Price 40: $2.90 - $5.80
# Price 41: $19.78 - $28.77
# Price 42: $19.78 - $28.77
# Price 43: $10.50 - $11.00
# Price 44: $8.10 - $9.80
# Price 45: $0.35 - $22.00
# Price 46: $18.00 - $19.90
# Price 47: $7.66 - $8.25
# Price 48: $3.00 - $3.60

# %%
# # Function to extract price range
# def extract_price_range(text):
#     # Use regular expression to match price range pattern
#     match = re.search(r'\$\s*([\d.,]+)\s*-\s*\$\s*([\d.,]+)', text)
#     if match:
#         return f"${match.group(1)} - ${match.group(2)}"
#     else:
#         return None

# %%
# results_list = []

# # Iterate over each result
# for result_element in results_complete:
#     # Split the text into a list based on newline character '\n'
#     result_text = result_element.text
#     result_list = result_text.split('\n')

#     # Extracting price range using the function
#     price_range = extract_price_range(result_list[1])

#     # Create a dictionary to store the extracted data for the current result
#     result_dict = {
#         "Product Name": result_list[0],
#         "Price Range": price_range,
#         "Min. Order Quantity": next((x for x in result_list if "Min. order" in x), None),
#         "Supplier Name": next((x for x in result_list if "Supplier" in x), None),
#         "Supplier Experience": next((x for x in result_list if "yr" in x), None),
#         "Supplier Location": next((x for x in result_list if "CN" in x or "US" in x), None),
#         "Supplier Ratings": next((x for x in result_list if "/5.0" in x), None)
#     }

#     # Append the dictionary to the list
#     results_list.append(result_dict)

# # Create a pandas DataFrame from the list of dictionaries
# df = pd.DataFrame(results_list)
# df
# Out:
#                                          Product Name            Price Range  \
# 0   Refinecolor Newest Technology RF-CO1 Gold Coin...  $2,500.00 - $2,980.00
# 1   High-Quality to Sell Online 2023 Set With Ther...        $11.10 - $13.50
# 2   2023 unique products to sell online High Quali...        $11.10 - $13.20
# 3   Gift promotion customized Business business an...        $10.90 - $12.00
# 4   Chinese A5 PU Leather Notebook Gift Box Set Cr...          $1.60 - $3.40
# 5                            Easy ReturnReady to Ship                   None
# 6   High Quality Lovely Multimodal Gift Box Contai...          $6.29 - $7.52
# 7   wholesale high quality promotional business gi...          $0.45 - $1.88
# 8                            Easy ReturnReady to Ship                   None
# 9        Promotional ActivitiesNew Business Giveaways                   None
# 10                           Easy ReturnReady to Ship                   None
# 11  Business Gift Set Luxury Corporate Custom Busi...                   None
# 12       Promotional ActivitiesNew Business Giveaways                   None
# 13  Office Staff Gifts 3-in-1 Enterprise Gift Adva...          $5.63 - $6.98
# 14  Promotional ActivitiesThanksgivingNew Business...                   None
# 15  Wholesale New Idea Custom Gift Box Business Gi...          $0.38 - $0.43
# 16  new product ideas 2023 unique popular tall and...          $0.95 - $1.10
# 17                           Easy ReturnReady to Ship                   None
# 18  Unique products to sell online 2023 Gifts Sets...          $1.55 - $1.75
# 19  High Quality Low Price Modern Design Best Prom...          $0.12 - $2.99
# 20  Unique Products Sell Online San Valentines Who...          $5.98 - $9.97
# 21  AI-MICH Hot Selling Greeting Gift Card Clothin...         $5.99 - $12.90
# 22  herbal hair color novelty Christmas gifts for ...          $1.40 - $2.50
# 23  Luxury promotional gift set corporate gift set...          $4.75 - $5.50
# 24                           Easy ReturnReady to Ship                   None
# 25  Holiday Creative Gift Set Chinese style Notebo...        $14.40 - $16.00
# 26                           Easy ReturnReady to Ship                   None
# 27                           Easy ReturnReady to Ship                   None
# 28  unique products to sell online 2023 Luxury cus...         $6.53 - $10.87
# 29  Promotional ActivitiesThanksgivingNew Business...                   None
# 30  wholesale luxury custom business gift transpar...          $0.01 - $0.02
# 31  journal printing custom notebook gift set ther...        $17.75 - $17.99
# 32  Gadget 2022 New Arrival Unique Products To Sel...        $19.80 - $25.00
# 33  Customizable LOGO laptop office business gift ...          $6.70 - $9.00
# 34  Unique products to sell online business ideas ...        $20.13 - $22.90
# 35  Accept customized cheap wholesale decoration P...          $0.07 - $0.18
# 36  T51Top Hot Gift Creative Bear Towel Cute Soft ...          $0.50 - $1.50
# 37                                      Ready to Ship                   None
# 38  Exclusive Customised Brown Foldable Gift Box a...        $11.50 - $12.50
# 39  New Product Marketing Promotional Advertisemen...          $2.90 - $5.80
# 40  Business Gift Box Business Gift set Best gift ...        $19.78 - $28.77
# 41  Business Gift Box Business Gift set Best gift ...        $19.78 - $28.77
# 42  Chinese gift box thermos cup umbrella set busi...        $10.50 - $11.00
# 43                           Easy ReturnReady to Ship                   None
# 44  Myriver Unique Products Sell Online Business I...         $0.35 - $22.00
# 45                                      Ready to Ship                   None
# 46  Amazon hot sale electric wine stopper promotio...          $7.66 - $8.25
# 47  Promotional ActivitiesThanksgivingNew Business...                   None
#
#           Min. Order Quantity Supplier Name  \
# 0           Min. order: 1 set   CN Supplier
# 1      Min. order: 100 pieces   CN Supplier
# 2       Min. order: 50 pieces   CN Supplier
# 3        Min. order: 100 sets   CN Supplier
# 4      Min. order: 100.0 sets   CN Supplier
# 5       Min. order: 10 pieces   CN Supplier
# 6         Min. order: 2 boxes   CN Supplier
# 7       Min. order: 50 pieces   CN Supplier
# 8         Min. order: 10 sets   CN Supplier
# 9      Min. order: 100 pieces   CN Supplier
# 10       Min. order: 100 sets   CN Supplier
# 11       Min. order: 2.0 sets   CN Supplier
# 12   Min. order: 100.0 pieces   CN Supplier
# 13     Min. order: 100 pieces   CN Supplier
# 14     Min. order: 500 pieces   CN Supplier
# 15       Min. order: 2 pieces   CN Supplier
# 16      Min. order: 10 pieces   CN Supplier
# 17        Min. order: 10 sets   CN Supplier
# 18      Min. order: 49 pieces   CN Supplier
# 19   Min. order: 100.0 pieces   CN Supplier
# 20       Min. order: 5 pieces   CN Supplier
# 21     Min. order: 100 pieces   CN Supplier
# 22       Min. order: 2 pieces   CN Supplier
# 23     Min. order: 100 pieces   CN Supplier
# 24      Min. order: 50 pieces   CN Supplier
# 25     Min. order: 100.0 sets   CN Supplier
# 26       Min. order: 3 pieces   CN Supplier
# 27        Min. order: 1 piece   CN Supplier
# 28      Min. order: 100 boxes   CN Supplier
# 29      Min. order: 60 pieces   CN Supplier
# 30  Min. order: 1000.0 pieces   CN Supplier
# 31     Min. order: 2.0 pieces   CN Supplier
# 32       Min. order: 50 boxes   CN Supplier
# 33       Min. order: 3 pieces   CN Supplier
# 34       Min. order: 100 sets   CN Supplier
# 35      Min. order: 1.0 piece   CN Supplier
# 36   Min. order: 100.0 pieces   CN Supplier
# 37          Min. order: 1 bag   CN Supplier
# 38      Min. order: 20 pieces   IN Supplier
# 39     Min. order: 100 pieces   CN Supplier
# 40       Min. order: 20 boxes   CN Supplier
# 41       Min. order: 20 boxes   CN Supplier
# 42      Min. order: 50 pieces   CN Supplier
# 43     Min. order: 100 pieces   CN Supplier
# 44     Min. order: 2.0 pieces   CN Supplier
# 45       Min. order: 1 carton   CN Supplier
# 46      Min. order: 28 pieces   CN Supplier
# 47      Min. order: 30 pieces   CN Supplier
#
#                                   Supplier Experience  \
# 0                                               6 yrs
# 1                                                1 yr
# 2                                                1 yr
# 3                                               3 yrs
# 4                                               2 yrs
# 5                                                1 yr
# 6                                                1 yr
# 7                                               2 yrs
# 8                                               5 yrs
# 9                                               3 yrs
# 10                                              5 yrs
# 11                                              5 yrs
# 12                                             14 yrs
# 13                                               1 yr
# 14                                             10 yrs
# 15                                              8 yrs
# 16                                              3 yrs
# 17                                              6 yrs
# 18                                              8 yrs
# 19                                             16 yrs
# 20                                              2 yrs
# 21                                              4 yrs
# 22                                              4 yrs
# 23                                              4 yrs
# 24                                              3 yrs
# 25                                              5 yrs
# 26                                              4 yrs
# 27                                              5 yrs
# 28                                               1 yr
# 29                                              6 yrs
# 30                                             15 yrs
# 31                                              3 yrs
# 32                                              7 yrs
# 33                                               1 yr
# 34                                             16 yrs
# 35                                              8 yrs
# 36                                              4 yrs
# 37                                              4 yrs
# 38                                             10 yrs
# 39                                              3 yrs
# 40                                              2 yrs
# 41                                               1 yr
# 42                                              4 yrs
# 43                                              4 yrs
# 44  Myriver Unique Products Sell Online Business I...
# 45                                             14 yrs
# 46                                              5 yrs
# 47                                              3 yrs
#
#                                     Supplier Location Supplier Ratings
# 0                                         CN Supplier        /5.0 (75)
# 1                                         CN Supplier         /5.0 (1)
# 2                                         CN Supplier             None
# 3                                         CN Supplier        /5.0 (34)
# 4                                         CN Supplier         /5.0 (6)
# 5                                         CN Supplier             None
# 6                                         CN Supplier         /5.0 (3)
# 7                                         CN Supplier        /5.0 (10)
# 8                                         CN Supplier        /5.0 (21)
# 9                                         CN Supplier        /5.0 (39)
# 10                                        CN Supplier        /5.0 (11)
# 11                                        CN Supplier         /5.0 (4)
# 12                                        CN Supplier        /5.0 (12)
# 13                                        CN Supplier         /5.0 (1)
# 14                                        CN Supplier        /5.0 (18)
# 15                                        CN Supplier         /5.0 (3)
# 16                                        CN Supplier        /5.0 (28)
# 17                                        CN Supplier        /5.0 (40)
# 18                                        CN Supplier        /5.0 (50)
# 19                                        CN Supplier       /5.0 (385)
# 20                                        CN Supplier         /5.0 (2)
# 21                                        CN Supplier         /5.0 (9)
# 22                                        CN Supplier        /5.0 (69)
# 23                                        CN Supplier        /5.0 (36)
# 24                                        CN Supplier        /5.0 (20)
# 25                                        CN Supplier        /5.0 (72)
# 26                                        CN Supplier        /5.0 (26)
# 27                                        CN Supplier         /5.0 (3)
# 28                                        CN Supplier         /5.0 (1)
# 29                                        CN Supplier        /5.0 (14)
# 30                                        CN Supplier        /5.0 (75)
# 31                                        CN Supplier        /5.0 (16)
# 32                                        CN Supplier         /5.0 (2)
# 33  Customizable LOGO laptop office business gift ...        /5.0 (28)
# 34                                        CN Supplier         /5.0 (6)
# 35                                        CN Supplier        /5.0 (50)
# 36                                        CN Supplier        /5.0 (31)
# 37                                        CN Supplier         /5.0 (1)
# 38                                               None             None
# 39                                        CN Supplier        /5.0 (14)
# 40                                        CN Supplier             None
# 41                                        CN Supplier         /5.0 (3)
# 42                                        CN Supplier         /5.0 (4)
# 43                                        CN Supplier         /5.0 (1)
# 44                                        CN Supplier        /5.0 (19)
# 45                                        CN Supplier        /5.0 (99)
# 46                                        CN Supplier         /5.0 (1)
# 47                                        CN Supplier        /5.0 (30)
